# %% [markdown]
# # *Data Wrangling with Pandas*
# ##### Ooi Rui Zhe (23004947)

# %% [markdown]
# # Step 1: Data Loading
# * Download the dataset from Kaggle onto your local drive. Load the dataset into a Pandas
# DataFrame. The dataset must be in CSV format.

# %%
import pandas as pd 

df_house_data = pd.read_csv("dataset/house_data.csv") #load the csv dataset into a 'dataframe' df

df_house_data
# Out:
#                ID             Date      Price  Bedrooms  Bathrooms  \
# 0         1000102  20140916T000000   280000.0         6       3.00
# 1         1000102  20150422T000000   300000.0         6       3.00
# 2         1200019  20140508T000000   647500.0         4       1.75
# 3         1200021  20140811T000000   400000.0         3       1.00
# 4         2800031  20150401T000000   235000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 21607  9253900408  20150408T000000  1400000.0         3       2.75
# 21608  9253900417  20150128T000000  1600000.0         3       2.50
# 21609  9362000040  20140623T000000  3400000.0         3       4.50
# 21610  9412400220  20140710T000000  1610000.0         4       2.75
# 21611  9536600010  20141223T000000   520000.0         4       0.75
#
#        Sqft_living  Sqft_lot  Floors  Waterfront  View  Condition  Grade  \
# 0             2400      9373     2.0         NaN   NaN          3    7.0
# ...

# %% [markdown]
# # Step 2:  Initial Data Exploration
# * Display the first 5 rows of the dataset to get an initial sense of the data. You may use the info()
# and describe() functions to gather basic information about the dataset, such as data types,
# missing values, and summary statistics (e.g., min, max, mean, std deviation, and quartiles).

# %%
## i)Display the first 5 row of the dataset
df_house_data.head()
# Out:
#         ID             Date     Price  Bedrooms  Bathrooms  Sqft_living  \
# 0  1000102  20140916T000000  280000.0         6       3.00         2400
# 1  1000102  20150422T000000  300000.0         6       3.00         2400
# 2  1200019  20140508T000000  647500.0         4       1.75         2060
# 3  1200021  20140811T000000  400000.0         3       1.00         1460
# 4  2800031  20150401T000000  235000.0         3       1.00         1430
#
#    Sqft_lot  Floors  Waterfront  View  Condition  Grade  Sqft_above  \
# 0      9373     2.0         NaN   NaN          3    7.0        2400
# 1      9373     2.0         NaN   NaN          3    7.0        2400
# 2     26036     1.0         NaN   NaN          4    8.0        1160
# 3     43000     1.0         NaN   NaN          3    7.0        1460
# 4      7599     1.5         NaN   NaN          4    6.0        1010
#
#    Sqft_basement  Year_built  Year_renovated  Zipcode     City
# ...

# %%
## ii)Evaluate the data is good or not. Does it has enough samples?
df_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21612 entries, 0 to 21611
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              21612 non-null  int64
#  1   Date            21612 non-null  object
#  2   Price           21612 non-null  float64
#  3   Bedrooms        21612 non-null  int64
#  4   Bathrooms       21612 non-null  float64
#  5   Sqft_living     21612 non-null  int64
#  6   Sqft_lot        21612 non-null  int64
#  7   Floors          21612 non-null  float64
#  8   Waterfront      163 non-null    float64
#  9   View            2124 non-null   float64
#  10  Condition       21612 non-null  int64
#  11  Grade           21574 non-null  float64
#  12  Sqft_above      21612 non-null  int64
#  13  Sqft_basement   21612 non-null  int64
#  14  Year_built      21602 non-null  float64
#  15  Year_renovated  914 non-null    float64
#  16  Zipcode         21612 non-null  int64
# ...

# %% [markdown]
# * From df_house_data.info(), the datasset has has 21613 samples, or row of observation of 18 columns. Since the samples exceed 20000, the number of samples is quite enough.

# %%
##iii) How many features does it have? Is it enough?

# %% [markdown]
# * From df.info(), the dataset has 18 columns. Thus, it will have 17 features that help to determine 1 target output which is the house sales.(target output = house sales). I think 17 features is adequate for this data analysis because they encompass a comprehensive range of factors that are likely to influence the house sales, such as number of bedrooms,bathrooms,square feett living and more.

# %%
##iv) What are the datatypes does the dataset consist of?

# %%
df_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21612 entries, 0 to 21611
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              21612 non-null  int64
#  1   Date            21612 non-null  object
#  2   Price           21612 non-null  float64
#  3   Bedrooms        21612 non-null  int64
#  4   Bathrooms       21612 non-null  float64
#  5   Sqft_living     21612 non-null  int64
#  6   Sqft_lot        21612 non-null  int64
#  7   Floors          21612 non-null  float64
#  8   Waterfront      163 non-null    float64
#  9   View            2124 non-null   float64
#  10  Condition       21612 non-null  int64
#  11  Grade           21574 non-null  float64
#  12  Sqft_above      21612 non-null  int64
#  13  Sqft_basement   21612 non-null  int64
#  14  Year_built      21602 non-null  float64
#  15  Year_renovated  914 non-null    float64
#  16  Zipcode         21612 non-null  int64
# ...

# %% [markdown]
# * From df.info(), most of the columns in the dataset consists of 'int64' datatype and 'float64' datatype.
#
# * Datatype:
#     * int64  : ID, Bedrooms, Sqft_living, Sqft_lot, Condition, 'Sqft_above', 'Sqft_basement','Zipcode'
#     * float64: Price, Bathrooms, Floors, Waterfront , View, Grade, Year_built, Year_renovated
#     * object : Date, City
#
# * However, in my opinion i think 'Year_built' and 'Year_renovated' should be in the format of 'int64', not in 'float64' datatype.
#
# * The 'float64' datatype is used for 'Bathrooms' because the decimal places represent the various conditions and fixtures present in US bathrooms.
# * For example:
#   *  2.5 bath would be two full bathrooms, and one half bathroom
#   *
# 1.75 bath would mean one full bathroom, and one 3/4 bathroom  *
# 1.5 would mean one full bathroom, and one half bathroo  *  m
# 2.25 would be a full bathroom, a three-quarter bathroom, and a half bathr
#
# *  The 'float64' datatype is also used for 'Floors' to help offering a detailed and precise description of the property layout og the house.
# *  For example:
#   * 1.5 Floor: a partial second floor is added to allow for more space*

# %%
##v) Which columns have missing/null values? How many rows that have missing/null values?

# %%
df_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21612 entries, 0 to 21611
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              21612 non-null  int64
#  1   Date            21612 non-null  object
#  2   Price           21612 non-null  float64
#  3   Bedrooms        21612 non-null  int64
#  4   Bathrooms       21612 non-null  float64
#  5   Sqft_living     21612 non-null  int64
#  6   Sqft_lot        21612 non-null  int64
#  7   Floors          21612 non-null  float64
#  8   Waterfront      163 non-null    float64
#  9   View            2124 non-null   float64
#  10  Condition       21612 non-null  int64
#  11  Grade           21574 non-null  float64
#  12  Sqft_above      21612 non-null  int64
#  13  Sqft_basement   21612 non-null  int64
#  14  Year_built      21602 non-null  float64
#  15  Year_renovated  914 non-null    float64
#  16  Zipcode         21612 non-null  int64
# ...

# %% [markdown]
# * This dataset has FIVE columns with null values. They are column 'Waterfront', 'View' , 'Grade', 'Year_built','Year_renovated'.
# * From df.info(), we can find out that this dataset have 21613 rows and 17 columns.
#
# * Null values :
#   * Waterfront     : 21613 -   163 = 21450 (Too many NULL values)
#   * View           : 21613 -  2124 = 19489 (Too many NULL values)
#   * Grade          : 21613 - 21575 =    38 (some NULL values)
#   * Year_built     : 21613 - 21603 =    10 (some NULL values)
#   * Year_renovated : 21613 -   914 = 20699 (Too many NULL values)

# %%
## vi) Summary statistics for each columns 
df_house_data.describe()
# Out:
#                  ID         Price      Bedrooms     Bathrooms   Sqft_living  \
# count  2.161200e+04  2.161200e+04  21612.000000  21612.000000  21612.000000
# mean   4.580402e+09  5.401775e+05      3.369471      2.114774   2079.921016
# std    2.876594e+09  3.673701e+05      0.907982      0.770177    918.456818
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.218375e+05      3.000000      1.750000   1426.500000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     11.000000      8.000000  13540.000000
#
#            Sqft_lot        Floors  Waterfront         View     Condition  \
# count  2.161200e+04  21612.000000       163.0  2124.000000  21612.000000
# mean   1.510739e+04      1.494332         1.0     2.384181      3.409356
# ...

# %% [markdown]
# * By using df_house_data.describe(), we can find out the summary statistics (e.g., min, max, mean, std deviation, and quartiles) for each columns as shown above.

# %% [markdown]
# # Step 3: Data Cleaning
# * Handle missing values using appropriate Panda codes: If there are missing values in the dataset, decide on a strategy to deal with them (e.g., fill with a specific value or drop rows row columns). Check for and handle duplicate entries if they exist.

# %% [markdown]
# ### * Incomplete (Missing Values)

# %% [markdown]
# ##### Using df_house_data.info(), we can find out that there are columns with a lot of missing values and some columns with only few missing values.
#
# * Columns with missing/Null values (Count using df_house_data.info()):
#
#   * Waterfront     : 21613 -   163 = 21450 (Too many NULL values)
#   * View           : 21613 -  2124 = 19489 (Too many NULL values)
#   * Grade          : 21613 - 21575 =    38 (some NULL values)
#   * Year_built     : 21613 - 21603 =    10 (some NULL values)
#   * Year_renovated : 21613 -   914 = 20699 (Too many NULL values)

# %% [markdown]
# ##### We can double check the missing values using below coding :

# %%
print('--Columns and the number of missing values--')

df_house_data.isna().sum()
# Out:
# --Columns and the number of missing values--
# ID                    0
# Date                  0
# Price                 0
# Bedrooms              0
# Bathrooms             0
# Sqft_living           0
# Sqft_lot              0
# Floors                0
# Waterfront        21449
# View              19488
# Condition             0
# Grade                38
# Sqft_above            0
# Sqft_basement         0
# Year_built           10
# Year_renovated    20698
# Zipcode               0
# City                  0
# dtype: int64

# %% [markdown]
# ### i) Dropping columns with too many missing values

# %% [markdown]
# * Columns with too many missing values are 'Waterfront','View' and 'Year_renovated';hence, we will drop these three columns.

# %%
##Before dropping the three columns
print(df_house_data.columns)
# Out:
# Index(['ID', 'Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living',
#        'Sqft_lot', 'Floors', 'Waterfront', 'View', 'Condition', 'Grade',
#        'Sqft_above', 'Sqft_basement', 'Year_built', 'Year_renovated',
#        'Zipcode', 'City'],
#       dtype='object')

# %%
#Drop columns 'Waterfront', 'View', 'Year_renovated' using df_house_data.drop()
df_new = df_house_data.drop(columns = ['Waterfront','View','Year_renovated'])

##Check existing data after dropping
print(df_new.columns)
# Out:
# Index(['ID', 'Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living',
#        'Sqft_lot', 'Floors', 'Condition', 'Grade', 'Sqft_above',
#        'Sqft_basement', 'Year_built', 'Zipcode', 'City'],
#       dtype='object')

# %%
##Successfully dropped columns 'Waterfront','View'&'Year_renovated'
df_new.head()
# Out:
#         ID             Date     Price  Bedrooms  Bathrooms  Sqft_living  \
# 0  1000102  20140916T000000  280000.0         6       3.00         2400
# 1  1000102  20150422T000000  300000.0         6       3.00         2400
# 2  1200019  20140508T000000  647500.0         4       1.75         2060
# 3  1200021  20140811T000000  400000.0         3       1.00         1460
# 4  2800031  20150401T000000  235000.0         3       1.00         1430
#
#    Sqft_lot  Floors  Condition  Grade  Sqft_above  Sqft_basement  Year_built  \
# 0      9373     2.0          3    7.0        2400              0      1991.0
# 1      9373     2.0          3    7.0        2400              0      1991.0
# 2     26036     1.0          4    8.0        1160            900      1947.0
# 3     43000     1.0          3    7.0        1460              0      1952.0
# 4      7599     1.5          4    6.0        1010            420      1930.0
#
#    Zipcode     City
# 0    98002   Auburn
# 1    98002   Auburn
# ...

# %% [markdown]
# ### ii) Dropping rows with missing values (Column Year_built)

# %%
df_dropna = df_new.dropna(subset=['Year_built'])
df_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21602 entries, 0 to 21611
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             21602 non-null  int64
#  1   Date           21602 non-null  object
#  2   Price          21602 non-null  float64
#  3   Bedrooms       21602 non-null  int64
#  4   Bathrooms      21602 non-null  float64
#  5   Sqft_living    21602 non-null  int64
#  6   Sqft_lot       21602 non-null  int64
#  7   Floors         21602 non-null  float64
#  8   Condition      21602 non-null  int64
#  9   Grade          21564 non-null  float64
#  10  Sqft_above     21602 non-null  int64
#  11  Sqft_basement  21602 non-null  int64
#  12  Year_built     21602 non-null  float64
#  13  Zipcode        21602 non-null  int64
#  14  City           21602 non-null  object
# dtypes: float64(5), int64(8), object(2)
# memory usage: 2.6+ MB

# %%
## Succesfully dropped the 10 rows with missing values in column 'Year_built'

# %% [markdown]
# ### iii) Replacing missing value using Mean along each column in Column 'Grade'

# %%
##print out rows for columngrade with missing values
# Filter rows where 'Grade' column has null values
rows_nullgrade = df_dropna[df_dropna['Grade'].isnull()]

# Print the all the rows with missing values in column 'Grade'
rows_nullgrade
# Out:
#                ID             Date      Price  Bedrooms  Bathrooms  \
# 783     405100295  20140826T000000   265000.0         3       1.75
# 1106    582000135  20140622T000000   565000.0         2       1.75
# 1304    686500030  20141202T000000   650000.0         6       2.75
# 1511    809001525  20140625T000000   890000.0         4       1.00
# 1891   1023059465  20140513T000000   505000.0         4       2.50
# 3212   1483300570  20140908T000000   905000.0         4       2.50
# 5120   2207500200  20140915T000000   615000.0         3       1.75
# 5305   2310000240  20150313T000000   275000.0         3       2.25
# 5433   2346200030  20150105T000000   802541.0         5       2.75
# 5634   2450000295  20141007T000000  1090000.0         3       2.50
# 5645   2459500310  20150218T000000   358000.0         3       2.25
# 5726   2473360060  20150102T000000   263500.0         3       1.75
# 6620   2770603523  20150422T000000   530000.0         3       2.50
# ...

# %%
# Replace missing values with the mean in a new DataFrame
mean_grade = df_dropna['Grade'].mean()

df_new_filled = df_dropna.copy()  # Create a copy 
df_new_filled['Grade'] = df_new_filled['Grade'].fillna(mean_grade)

# %%
df_new_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21602 entries, 0 to 21611
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             21602 non-null  int64
#  1   Date           21602 non-null  object
#  2   Price          21602 non-null  float64
#  3   Bedrooms       21602 non-null  int64
#  4   Bathrooms      21602 non-null  float64
#  5   Sqft_living    21602 non-null  int64
#  6   Sqft_lot       21602 non-null  int64
#  7   Floors         21602 non-null  float64
#  8   Condition      21602 non-null  int64
#  9   Grade          21602 non-null  float64
#  10  Sqft_above     21602 non-null  int64
#  11  Sqft_basement  21602 non-null  int64
#  12  Year_built     21602 non-null  float64
#  13  Zipcode        21602 non-null  int64
#  14  City           21602 non-null  object
# dtypes: float64(5), int64(8), object(2)
# memory usage: 2.6+ MB

# %%
##Check whether all the missing values in column grade is filled with the mean values for grade
mask = (df_new_filled['Grade'] == mean_grade)

# Print the rows where 'Grade' is equal to the mean
df_new_filled[mask]
# Out:
#                ID             Date      Price  Bedrooms  Bathrooms  \
# 783     405100295  20140826T000000   265000.0         3       1.75
# 1106    582000135  20140622T000000   565000.0         2       1.75
# 1304    686500030  20141202T000000   650000.0         6       2.75
# 1511    809001525  20140625T000000   890000.0         4       1.00
# 1891   1023059465  20140513T000000   505000.0         4       2.50
# 3212   1483300570  20140908T000000   905000.0         4       2.50
# 5120   2207500200  20140915T000000   615000.0         3       1.75
# 5305   2310000240  20150313T000000   275000.0         3       2.25
# 5433   2346200030  20150105T000000   802541.0         5       2.75
# 5634   2450000295  20141007T000000  1090000.0         3       2.50
# 5645   2459500310  20150218T000000   358000.0         3       2.25
# 5726   2473360060  20150102T000000   263500.0         3       1.75
# 6620   2770603523  20150422T000000   530000.0         3       2.50
# ...

# %% [markdown]
# ### iv) Check for and handle duplicate entries if they exist.

# %%
## Check is there any duplicate entries in Location
# Count and print the number of cities for each unique City category
City_counts = df_new_filled['City'].value_counts(dropna=False) 

# Print the counts for each unique item, including 'nan'
print('--Number of houses in that particular city--')
for City, count in City_counts.items():
    print(f"{City}: {count}")
# Out:
# --Number of houses in that particular city--
# Seattle: 7049
# Renton: 1595
# Redmond: 1262
# Bellevue: 1122
# Sammamish: 1120
# Hobart: 1001
# Auburn: 912
# Federal Way: 779
# SeaTac: 742
# Bothell: 740
# Tukwila: 573
# Covington: 548
# Kent: 530
# Cottage Lake: 471
# Shoreline: 446
# Kirkland: 432
# Tokul: 310
# Burien: 288
# Kenmore: 282
# Mercer Island: 282
# Naco: 234
# Garcia: 221
# Duvall: 190
# Carnation: 124
# Vashon: 118
# Black Diamond: 100
# Fall City: 81
# Medina: 50

# %% [markdown]
# * From the list above, there are no duplicate entries in the column 'City';hence, there's no duplicate entries to remove

# %% [markdown]
# ### v) Convert the datatypes for column 'Year_built' from 'float64' to 'Int64'

# %%
df_new_filled['Year_built'] = df_new_filled['Year_built'].fillna(0).astype('int64')

df_new_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21602 entries, 0 to 21611
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             21602 non-null  int64
#  1   Date           21602 non-null  object
#  2   Price          21602 non-null  float64
#  3   Bedrooms       21602 non-null  int64
#  4   Bathrooms      21602 non-null  float64
#  5   Sqft_living    21602 non-null  int64
#  6   Sqft_lot       21602 non-null  int64
#  7   Floors         21602 non-null  float64
#  8   Condition      21602 non-null  int64
#  9   Grade          21602 non-null  float64
#  10  Sqft_above     21602 non-null  int64
#  11  Sqft_basement  21602 non-null  int64
#  12  Year_built     21602 non-null  int64
#  13  Zipcode        21602 non-null  int64
#  14  City           21602 non-null  object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 2.6+ MB

# %% [markdown]
# # Step 4: Data Selection and Filtering
# * Select a subset of the data based on a specific condition (e.g., select rows where a particular column meets a certain criteria). Filter the data to include only the columns that are relevant to your analysis. You may use regex().

# %% [markdown]
# ### i) Data Selection: Selecting subset of rows (which meets a certain condition)

# %% [markdown]
# * For example, I would like to select subset of data of 3 columns, which is column 'Bedrooms' with value 4, column 'Condition' with value 4 and column 'City'that is 'Tokul'.

# %%
subset_data = df_new_filled[(df_new_filled['Bedrooms'] == 4) & (df_new_filled['Condition'] == 4) & (df_new_filled['City'] == 'Tokul')]

#Display out
subset_data
# Out:
#                ID             Date     Price  Bedrooms  Bathrooms  \
# 6266   2624089026  20141002T000000  275000.0         4       1.00
# 7297   3024089057  20150106T000000  282500.0         4       1.00
# 11861  5415000240  20150224T000000  330000.0         4       1.75
# 15691  7849201020  20140821T000000  335000.0         4       1.75
# 15692  7849201061  20150408T000000  319950.0         4       2.50
#
#        Sqft_living  Sqft_lot  Floors  Condition  Grade  Sqft_above  \
# 6266          1430     27153     1.5          4    5.0        1430
# 7297          1170     34925     1.0          4    6.0        1170
# 11861         1520     14417     1.0          4    7.0        1520
# 15691         1950     13440     1.5          4    6.0        1950
# 15692         2020      7200     1.5          4    6.0        2020
#
#        Sqft_basement  Year_built  Zipcode   City
# 6266               0        1934    98065  Tokul
# 7297               0        1942    98065  Tokul
# ...

# %% [markdown]
# ### ii) Data Filtering: Filter the Data to Include Only Relevant Columns Using Regex()

# %%
# Example: Filter columns using regex (e.g., columns containing 'Price' or 'Condition')
columns_filtered = df_new_filled.filter(regex='Price|Condition')

columns_filtered.head()
# Out:
#       Price  Condition
# 0  280000.0          3
# 1  300000.0          3
# 2  647500.0          4
# 3  400000.0          3
# 4  235000.0          4

# %% [markdown]
# # Step 5: Data Transformation
# * Create a new column that combines information from one existing column. Suppose you want to create a new column that combines a date (in datetime format) that combines one existing column, for e.g. total revenue of the day

# %% [markdown]
# #### i) Since columns 'Zipcode' and 'City' are correlated. I would like to create a new column that combines the Zipcode and City and the new column will be named as 'Location' to the cleaned data.

# %%
# Convert 'Zipcode' to string format before combining
df_new_filled['Zipcode'] = df_new_filled['Zipcode'].astype(str)

# Create new 'Location' column by combining 'Zipcode' and 'City'
df_new_filled['Location'] = df_new_filled['Zipcode'] + ' - ' + df_new_filled['City']

# Create a new DataFrame with only the 'Location' column
df_location = df_new_filled[['Location']].copy()

# Display the new DataFrame with 'Location' column
df_location
# Out:
#                     Location
# 0             98002 - Auburn
# 1             98002 - Auburn
# 2            98166 - Seattle
# 3            98166 - Seattle
# 4             98168 - SeaTac
# ...                      ...
# 21607        98008 - Redmond
# 21608        98008 - Redmond
# 21609  98040 - Mercer Island
# 21610        98118 - Seattle
# 21611         98198 - SeaTac
#
# [21602 rows x 1 columns]

# %%
df_new_filled.head()
# Out:
#         ID             Date     Price  Bedrooms  Bathrooms  Sqft_living  \
# 0  1000102  20140916T000000  280000.0         6       3.00         2400
# 1  1000102  20150422T000000  300000.0         6       3.00         2400
# 2  1200019  20140508T000000  647500.0         4       1.75         2060
# 3  1200021  20140811T000000  400000.0         3       1.00         1460
# 4  2800031  20150401T000000  235000.0         3       1.00         1430
#
#    Sqft_lot  Floors  Condition  Grade  Sqft_above  Sqft_basement  Year_built  \
# 0      9373     2.0          3    7.0        2400              0        1991
# 1      9373     2.0          3    7.0        2400              0        1991
# 2     26036     1.0          4    8.0        1160            900        1947
# 3     43000     1.0          3    7.0        1460              0        1952
# 4      7599     1.5          4    6.0        1010            420        1930
#
#   Zipcode     City         Location
# ...

# %% [markdown]
# * A new column 'Location' is successfully added to the cleaned data.

# %% [markdown]
# #### ii) Drop columns 'Zipcode' and 'City' after adding the new column 'Location'

# %%
#Drop columns 'Zipcode', 'City' using .drop()
df_step5 = df_new_filled.drop(columns = ['Zipcode','City'])

##Check existing data after dropping
print(df_step5.columns)
# Out:
# Index(['ID', 'Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living',
#        'Sqft_lot', 'Floors', 'Condition', 'Grade', 'Sqft_above',
#        'Sqft_basement', 'Year_built', 'Location'],
#       dtype='object')

# %%
##print the first 5 rows after dropping columns 'Zipcode' and 'City'
df_step5.head()
# Out:
#         ID             Date     Price  Bedrooms  Bathrooms  Sqft_living  \
# 0  1000102  20140916T000000  280000.0         6       3.00         2400
# 1  1000102  20150422T000000  300000.0         6       3.00         2400
# 2  1200019  20140508T000000  647500.0         4       1.75         2060
# 3  1200021  20140811T000000  400000.0         3       1.00         1460
# 4  2800031  20150401T000000  235000.0         3       1.00         1430
#
#    Sqft_lot  Floors  Condition  Grade  Sqft_above  Sqft_basement  Year_built  \
# 0      9373     2.0          3    7.0        2400              0        1991
# 1      9373     2.0          3    7.0        2400              0        1991
# 2     26036     1.0          4    8.0        1160            900        1947
# 3     43000     1.0          3    7.0        1460              0        1952
# 4      7599     1.5          4    6.0        1010            420        1930
#
#           Location
# 0   98002 - Auburn
# 1   98002 - Auburn
# ...

# %% [markdown]
# # Step 6: Data Aggregation
# * Group the data by a particular column and calculate summary statistics (e.g., mean, sum) for
# other columns within each group. For example, by grouping using groupby() the data by mont
# and calculating the total revenue for each mont.

# %% [markdown]
# #### i) Using groupby() for the column 'Location' to calculate summary statistics (e.g., mean, min, max) for other columns. This helps to provide insights into how housing prices, sizes, or other features vary across different regions within King County, USA.

# %%
## Exclude columns with datatypes 'object'
numeric_col = df_step5.select_dtypes(include=['float64', 'int64'])

# Group by 'Location' and aggregate only numeric columns
summary_stats_location = df_step5.groupby('Location')[numeric_col.columns].agg(['min', 'max', 'mean'])

#Print the first 5th rows of the stats out
summary_stats_location.head()
# Out:
#                             ID                               Price             \
#                            min         max          mean       min        max
# Location
# 98001 - Auburn       128500260  9543000945  4.664787e+09  100000.0   850000.0
# 98002 - Auburn         1000102  9500900430  4.850894e+09   95000.0   389000.0
# 98003 - Federal Way  100500020  9358400150  4.674182e+09  128000.0   950000.0
# 98004 - Bellevue     249000115  9809000020  4.411174e+09  425000.0  7060000.0
# 98005 - Bellevue     324059112  9560700055  4.961872e+09  400000.0  1960000.0
#
#                                   Bedrooms               Bathrooms  ...  \
#                              mean      min max      mean       min  ...
# Location                                                            ...
# 98001 - Auburn       2.808047e+05        0   6  3.383978      0.00  ...
# 98002 - Auburn       2.342840e+05        1   6  3.326633      0.75  ...
# ...

# %% [markdown]
# #### ii) Using groupby() for the column 'Grade' to calculate summary statistics (e.g., mean, min, max) for specific columns like column 'Price','Bedrooms','Bathrooms','Grade','Condition'. This offer insights into how different grades impact on these 5 variables.

# %%
# List of columns to include
columns_include = ['Price', 'Bedrooms', 'Bathrooms', 'Grade', 'Condition']

# Select only specified columns and filter numeric columns
numeric_col2 = df_step5[columns_include].select_dtypes(include=['float64', 'int64'])

# Group by 'Grade' and aggregate only specified columns
summary_stats_grade = df_step5.groupby('Grade')[numeric_col2.columns].agg(['min', 'max', 'mean'])

#Print the stats out
summary_stats_grade
# Out:
#                Price                          Bedrooms                \
#                  min        max          mean      min max      mean
# Grade
# 1.000000    142000.0   142000.0  1.420000e+05        0   0  0.000000
# 3.000000     75000.0   280000.0  2.056667e+05        1   1  1.000000
# 4.000000     80000.0   435000.0  2.143810e+05        0   3  1.482759
# 5.000000     78000.0   795000.0  2.485240e+05        1   6  2.388430
# 6.000000     82000.0  1200000.0  3.019828e+05        1   7  2.686149
# 7.000000     90000.0  2050000.0  4.024542e+05        0  11  3.252650
# 7.656557    219000.0  3080000.0  6.573011e+05        2   7  3.473684
# 8.000000    140000.0  3070000.0  5.426678e+05        0   9  3.479590
# 9.000000    230000.0  2700000.0  7.736557e+05        1  10  3.773390
# 10.000000   316000.0  3600000.0  1.069772e+06        1   8  3.907244
# 11.000000   420000.0  7060000.0  1.496656e+06        2   9  4.153266
# ...

# %% [markdown]
# #### iii) Using groupby() for the column 'Bedrooms' to calculate summary statistics (e.g., mean, sum) for only one specific columns like column 'Price'.

# %%
# List of columns to include
columns_include = ['Price']

# Select only specified columns and filter numeric columns
numeric_col3 = df_step5[columns_include].select_dtypes(include=['float64', 'int64'])

# Group by 'Bedrooms' and aggregate only specified columns
summary_stats_bed = df_step5.groupby('Bedrooms')[numeric_col3.columns].agg(['min', 'max', 'mean'])

#Print the stats out
summary_stats_bed
# Out:
#              Price
#                min        max          mean
# Bedrooms
# 0         139950.0  1300000.0  4.102231e+05
# 1          75000.0  1250000.0  3.176580e+05
# 2          78000.0  3280000.0  4.013877e+05
# 3          82000.0  3800000.0  4.662374e+05
# 4         100000.0  4490000.0  6.353977e+05
# 5         133000.0  7060000.0  7.865347e+05
# 6         175000.0  7700000.0  8.258535e+05
# 7         280000.0  3200000.0  9.514478e+05
# 8         340000.0  3300000.0  1.105077e+06
# 9         450000.0  1400000.0  8.939998e+05
# 10        650000.0  1150000.0  8.200000e+05
# 11        520000.0   520000.0  5.200000e+05

# %% [markdown]
# * This table illustrates how home prices differ based on the number of bedrooms. It shows the lowest(min), highest(max), and average(mean prices for homes with varying bedroom counts, giving insights into the price range across different property sizes.

# %% [markdown]
# # Step 7: Data Visualization
# * Create at least two data visualizations using Matplotlib or Seaborn to illustrate trends or insights
# in the data (e.g., bar chart, scatter plot, histogram).

# %% [markdown]
# ### i)Histogram:

# %%
plt.figure(figsize=(12, 4))   #12 units wide and 4 units high

# House Price Distribution
plt.subplot(1, 3, 1)  #First subplot
sns.histplot(df_step5['Price'], alpha = .9, bins=20)   #alpha control colour brightness, bins control chart thickness
plt.title('House Price Distribution')   #title

# Frequency of Bedrooms Counts
plt.subplot(1, 3, 2) #Second subplot
sns.histplot(df_step5['Bedrooms'], alpha =.6,bins=10)
plt.title('Frequency of Bedrooms Counts') 

# Frequency of Bathroom Counts
plt.subplot(1, 3, 3)  #Third subplot
sns.histplot(df_step5['Bathrooms'], alpha = .3, bins=10)
plt.title('Frequency of Bathroom Counts')

plt.tight_layout()  #Adjusts the subplots to prevent overlapping.
plt.show()  #Display

#source: https://medium.com/analytics-vidhya/an-introduction-to-subplots-in-matplotlib-b8b4821b47d1

# %% [markdown]
# * By using Matplotlib, three subplots are generated horizontally.
# * The first subplot shows the house price distribution, the house prices is skewed to the right,the mode for the house prices is between 600000 to 800000 USD.
# * The second subplot shows the frequency of the bedroom counts in the house sales data.The mode for the bedroom counts is around the value less than 5.
# * The third subplot shows the frequency of bathroom counts in the house sales data. The mode of the bathrooms count is 3.

# %% [markdown]
# ### ii) Scatter Plot

# %%
plt.figure(figsize=(12, 4))

# Sqft_living vs. Price
plt.subplot(1, 3, 1) #First subplot
plt.scatter(df_step5['Sqft_living'], df_step5['Price'])  #Scatter plot[x-axis,y-axis]
plt.xlabel('Sqft_living')  #x-axis
plt.ylabel('Price')  #y-axis
plt.title('Sqft_living vs Price')  #Title

# Sqft_lot vs. Price
plt.subplot(1, 3, 2) #Second subplot
plt.scatter(df_step5['Sqft_lot'], df_step5['Price'])
plt.xlabel('Sqft_lot')
plt.ylabel('Price')
plt.title('Sqft_lot vs Price')

# Year_built vs. Price
plt.subplot(1, 3, 3) #Second subplot
plt.scatter(df_step5['Year_built'], df_step5['Price'])
plt.xlabel('Year_built')
plt.ylabel('Price')
plt.title('Year_built vs Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Three scatter plot subplots are generated horizontally using only Matplotlib.
# * For the first scatter plot, Sqft_living vs Price, the scatter plot shows that larger square feet living spaces tend to correspond to higher house prices. Although there's still some house with higher square feet living spaces with lower house prices. At the same time, the square feet living data is clustered between 500-4000 square feet living spaces.
# * For the second scatter plot, Sqft_lot vs Price, the data is clustered on the left side.
# * For the third scatter plot, Year_built vs Price, the data is uniformly scattered.There are no changes in house prices concerning the  construction year of the properties.

# %% [markdown]
# ### iii) Bar Chart

# %%
plt.figure(figsize=(12, 6)) #12 units wide and 6 units high

# Condition
plt.subplot(1, 2, 1)  #First subplot
df_step5['Condition'].value_counts().sort_index().plot(kind='bar')  
plt.xlabel('Condition')
plt.ylabel('Frequency')
plt.title('Frequency of Houses based on Condition')

# Floors
plt.subplot(1, 2, 2) #Second subplot
df_step5['Floors'].value_counts().sort_index().plot(kind='bar')  #counts the occurrences of each unique value,sorts the results by the index, creates a bar chart visualization using Matplotlib
plt.xlabel('Number of Floors') #x-axis
plt.ylabel('Frequency') #y-axis
plt.title('Distribution of Houses based on House Floors') #title

plt.tight_layout()
plt.show()

# %% [markdown]
# * Two bar chart subplots are generated horizontally using only Matplotlib.
# * For the first bar chart, frequency of house based on condition, the data shows a mode of 3 for the house condition.
# * For the second scatter plot, distribution of houses based on house floors, the bar chart shows house with one floor is the highest, which is more than 10000.

# %% [markdown]
# # Step 8: Data Export
# * Save the cleaned and transformed dataset to a CSV file for future analysis.

# %%
df_step5.to_csv('house_sales-cleaned.csv')  ##export cleaned data into csv files

# %% [markdown]
# * A cleaned dataset is succesfully exported.

# %% [markdown]
# # Step 9: Documentation
# * Provide comments and explanations in your code cells to describe the steps you've taken by using the markdown feature in Jupiter.

# %% [markdown]
# #### All the explanations and further elaborations have been added on every steps

# %% [markdown]
# #### A Summary from Step 1-8:
# * Step 1: Import pandas, Load and Read data using pd.read_csv
# * Step 2: Display dataset, Evaluate data(whether it is enough samples), Check features, Check all the datatypes, Check missing values, Display summary statistics for each columns
# * Step 3: Clean the data by dropping columns with many null values, dropping rows with a missing values, replace missing values with a value(mean), handle duplicate values(if exist),convert column feature to correct datatype
# * Step 4: Select subset of rows, Filter data to include relevant columns
# * Step 5: Create new column that combines information from existing column
# * Step 6: Grouping data by particular column and aggregate summary statistics for other columns.
# * Step 7: Create data visualization(Histogram,Scatter plot, Bar Chart)
# * Step 8: Export cleaned and transformed data to csv

# %% [markdown]
# # Step 10: Conclusion
# * Summarize your findings, insights, and trends from the data wrangling process. Explain how the
# dataset can be laveraged for decision-making making. What type of Machine learning problems
# e.g. classification / clustering / regression is suitable for the dataset and decision-making.

# %% [markdown]
# ### i)Summarize your findings,insights and trends from data wrangling process
# * Identifying and understanding your own datasets is very important to ease the cleaning process of the data before the data is used. This includes evaluating the data size,determining the features of the data, datatypes of the data and missing values of the data.
# * Cleaning datasets is pertinent so that the data used is accurate, relevant especially when generating summary statistics that help to provide insights into relationships between different features.
# * Data selection and filtering helps to isolate the most relevent information that you need by extracting subsets or including relevent columns or rows from the dataset.
# * Data transforming helps to integrate disparate information, enabling a more comprehensive analysis from data.
# * Utilizing data grouping techniques helps to aggregate statistics(min, max , mean) based on specific columns, providing insights regarding the relationships between different features.
# * Using data visualization like bar chart, scatter plot and histograms helps in analysing distributions, correlations, and frequency distributions within the dataset. For example, the scatter plot of 'Sqft_living vs. Price' helps to illustrate how living area size correlates with house prices.

# %% [markdown]
# ### ii) How dataset can be leveraged for decision-making making
# * The dataset will help in property classification. For example, thes dataset helps incategorising similar houses based on those features in the dataset like bathrooms and bedrooms available, year of construction, square feet living, condition and more.
#
# * The dataset also helps in determing house prices.(real estate valuation) With this dataset, several summary statistics , insights data visualization can generated that helps in estimating house prices based on the distributions and correlations of the features in the dataset.
#
# * This dataset also helps in determining market trends. It helps to provide insights by understanding what buyers prefer using the historical data of the dataset.
#
# * This dataset also assists in investment decisions.It offers insights and relevent information about what makes a property valuable, aiding investors in selecting properties likely to appreciate in value.
#
# * This dataset is also useful for optimization of property features. The dataset helps in designing and renovating the properties that suits buyers' need and align with market trend based on the data analysis..

# %% [markdown]
# ### What type of Machine learning problems e.g. classification / clustering / regression is suitable for the dataset and decision-making
# * Classification:
#   * House Rating based on condition, facilities, or neighborhood features
#   * Predicting the condition of houses as poor, fair, good,great, or excellent
#
# * Clustering:
#   * Identifying groups of houses based on geographical locations, such as urban, suburban, or rural areas
#   * Clustering houses based on neighborhood characteristics or historical background of the properties
#
# * Regression:
#   * House Price Prediction based on square footage, number of bedrooms or bathrooms, and other property attributes
#   * Real Estate Valuation using historical sales data and property features
